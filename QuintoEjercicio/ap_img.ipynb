# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('imagen4.jpg',cv2.IMREAD_GRAYSCALE)
img_neg=255-img

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen Original')
plt.imshow(img,cmap='gray')
plt.subplot(1,2,2)
plt.title('Imagen Negativa')
plt.imshow(img_neg,cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('imagen4.jpg')
img_neg=255-img

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen Original')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2)
plt.title('Imagen Negativa')
plt.imshow(cv2.cvtColor(img_neg, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def contraste(img,factor=3.0):
    img=img.astype(np.float32)
    media=np.mean(img)
    img_contraste=media+(img-media)*factor
    img_contraste=np.clip(img_contraste,0,255).astype(np.uint8)
    return img_contraste
img=cv2.imread('imagen4.jpg',cv2.IMREAD_GRAYSCALE)
contrast=8
img_fin=contraste(img,contrast)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen Original')
plt.imshow(img,cmap='gray')
plt.subplot(1,2,2)
plt.title('Imagen Contraste')
plt.imshow(img_fin,cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def contraste(img,factor=3.0):
    img=img.astype(np.float32)
    media=np.mean(img)
    for i in range(3):
        media=np.mean(img[:,:,i])
        img[:,:,i]=media+(img[:,:,i]-media)*factor
        img[:,:,i]=np.clip(img[:,:,i],0,255)
    return img.astype(np.uint8)
img=cv2.imread('imagen4.jpg')
contrast=10
img_fin=contraste(img,contrast)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen Original')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2)
plt.title('Imagen Contraste')
plt.imshow(cv2.cvtColor(img_fin, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def brillo(img,brillo=0):
    img_brillo=img.astype(np.float32)+brillo
    img_brillo=np.clip(img_brillo,0,255).astype(np.uint8)
    return img_brillo
img=cv2.imread('imagen4.jpg',0)
brill=100#o -100
img_fin=brillo(img,brill)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen Original')
plt.imshow(img,cmap='gray')
plt.subplot(1,2,2)
plt.title('Imagen Brillo')
plt.imshow(img_fin,cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def brillo(img,brillo=0):
    for i in range(3):
        img[:,:,i]=img.astype(np.float32)+brillo
        img[:,:,i]=np.clip(img[:,:,i],0,255)
    return img.astype(np.uint8)
img=cv2.imread('imagen4.jpg')
brill=10#o -100
img_fin=brillo(img,brill)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen Original')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2)
plt.title('Imagen Brillo')
plt.imshow(cv2.cvtColor(img_fin, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 11
#       9 img=cv2.imread('imagen4.jpg')
#      10 brill=10#o -100
# ---> 11 img_fin=brillo(img,brill)
#      13 plt.figure(figsize=(10,5))
#      14 plt.subplot(1,2,1)
#
# Cell In[32], line 6, in brillo(img, brillo)
#       4 def brillo(img,brillo=0):
#       5     for i in range(3):
# ----> 6         img[:,:,i]=img.astype(np.float32)+brillo
#       7         img[:,:,i]=np.clip(img[:,:,i],0,255)
#       8     return img.astype(np.uint8)
#
# ValueError: could not broadcast input array from shape (914,1280,3) into shape (914,1280)
