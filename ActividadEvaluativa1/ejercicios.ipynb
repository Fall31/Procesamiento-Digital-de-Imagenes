# %% [markdown]
# EJERCICIO 1

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
imagen1 = cv2.imread('imagenP.jpg.jpeg')
imagen1=cv2.cvtColor(imagen1, cv2.COLOR_BGR2RGB)
x1=550
y1=450
x2=800
y2=750

recorte=imagen1[y1:y2, x1:x2]
plt.imsave('recorte.jpg', recorte)
plt.subplot(1,2,1)
plt.imshow(imagen1)
plt.title('Imagen Original')
plt.subplot(1,2,2)
plt.imshow(recorte)
plt.title('Recorte')
# Out:
# Text(0.5, 1.0, 'Recorte')

# %% [markdown]
# EJERCICIO 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

size = 255

img = np.zeros((size,size,3), dtype=np.float32)

for i in range(size):
    color = i/size
    img[i,:,0] = color*0.6
    img[i,:,1] = color*1
    img[i,:,2] = 1-color


plt.imsave('degradado.jpg', img)
plt.imshow(img)
plt.show()

# %% [markdown]
# EJERCICIO 3

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [10, 5]
size_imagen=800
imagen = np.ones((size_imagen, size_imagen, 3), dtype=np.uint8) * 255

primerOctavo = size_imagen // 8
segundoOctavo = size_imagen // 4
tercerOctavo = size_imagen // 8 * 3
cuartoOctavo = size_imagen // 2
quintoOctavo = size_imagen // 8 * 5
sextoOctavo = size_imagen // 8 * 6
septimoOctavo = size_imagen // 8 * 7

for i in range(size_imagen):
    for j in range(size_imagen):
        #Por filas
        if i < primerOctavo and j < primerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i <segundoOctavo and j < primerOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= tercerOctavo and i < cuartoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= quintoOctavo and i < sextoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= septimoOctavo and i < size_imagen and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        
         
        elif i < primerOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= segundoOctavo and i < tercerOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= sextoOctavo and i < septimoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]

        elif i < primerOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i < segundoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= quintoOctavo and i < sextoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= septimoOctavo and i < size_imagen and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [0, 0, 0]

        elif i < primerOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= segundoOctavo and i < tercerOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= sextoOctavo and i < septimoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 255]

        elif i < primerOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i < segundoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= quintoOctavo and i < sextoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= septimoOctavo and i < size_imagen and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [0, 0, 0]

        elif i < primerOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= segundoOctavo and i < tercerOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= sextoOctavo and i < septimoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 255]

        elif i < primerOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i < segundoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= quintoOctavo and i < sextoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= septimoOctavo and i < size_imagen and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [0, 0, 0]

        elif i < primerOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]
        elif i >= segundoOctavo and i < tercerOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]
        elif i >= sextoOctavo and i < septimoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]


plt.imsave('tablero.jpg', imagen)
plt.figure()
plt.imshow(imagen)
plt.title("Imagen con cuadrantes")
plt.show()

# %% [markdown]
# EJERCICIO 4

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def posterizar (imagen, niveles):
    factor_escala= 256 // niveles
    img_pos=np.round(imagen / factor_escala) * factor_escala
    return img_pos.astype(np.uint8)
def solarizar(imagen, umbral):
    img_sol = np.where(imagen < umbral, imagen, 255 - imagen)
    return img_sol
imagen = cv2.imread('degradado.jpg')
umbral = 127
img_sol = solarizar(imagen, umbral)

nvl = 1.5
img_pos = posterizar(imagen, nvl)

plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
plt.title('Original')
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))

plt.subplot(1,3,2)
plt.title('Solarizada')
plt.imshow(cv2.cvtColor(img_sol, cv2.COLOR_BGR2RGB))

plt.subplot(1,3,3)
plt.title('Posterizada')
plt.imshow(cv2.cvtColor(img_pos, cv2.COLOR_BGR2RGB))

plt.show()

# %% [markdown]
# EJERCICIO 5

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('imagen1.jpg')

size = 255

degradado = np.zeros((size,size,3), dtype=np.float32)

for i in range(size):
    color = i/size
    degradado[i,:,0] = color*0.6
    degradado[i,:,1] = color*1
    degradado[i,:,2] = 1-color

img_degradado = cv2.cvtColor(degradado, cv2.COLOR_BGR2RGB)
plt.imsave('imagen_degradado.jpg', img_degradado)
plt.imshow(img, img_degradado)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[296], line 18
#      16 img_degradado = cv2.cvtColor(degradado, cv2.COLOR_BGR2RGB)
#      17 plt.imsave('imagen_degradado.jpg', img_degradado)
# ---> 18 plt.imshow(img, img_degradado)
#      19 plt.show()
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
#    3610         colorizer=colorizer,
#    3611         origin=origin,
#    3612         extent=extent,
#    3613         interpolation_stage=interpolation_stage,
#    3614         filternorm=filternorm,
#    3615         filterrad=filterrad,
#    3616         resample=resample,
#    3617         url=url,
#    3618         **({"data": data} if data is not None else {}),
#    3619         **kwargs,
#    3620     )
#    3621     sci(__ret)
#    3622     return __ret
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\axes\_axes.py:5968, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5750 @_preprocess_data()
#    5751 @_docstring.interpd
#    5752 def imshow(self, X, cmap=None, norm=None, *, aspect=None,
#    (...)
#    5755            interpolation_stage=None, filternorm=True, filterrad=4.0,
#    5756            resample=None, url=None, **kwargs):
#    5757     """
#    5758     Display data as an image, i.e., on a 2D regular raster.
#    5759
#    (...)
#    5966     (unassociated) alpha representation.
#    5967     """
# -> 5968     im = mimage.AxesImage(self, cmap=cmap, norm=norm, colorizer=colorizer,
#    5969                           interpolation=interpolation, origin=origin,
#    5970                           extent=extent, filternorm=filternorm,
#    5971                           filterrad=filterrad, resample=resample,
#    5972                           interpolation_stage=interpolation_stage,
#    5973                           **kwargs)
#    5975     if aspect is None and not (
#    5976             im.is_transform_set()
#    5977             and not im.get_transform().contains_branch(self.transData)):
#    5978         aspect = mpl.rcParams['image.aspect']
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\image.py:884, in AxesImage.__init__(self, ax, cmap, norm, colorizer, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     867 def __init__(self, ax,
#     868              *,
#     869              cmap=None,
#    (...)
#     879              **kwargs
#     880              ):
#     882     self._extent = extent
# --> 884     super().__init__(
#     885         ax,
#     886         cmap=cmap,
#     887         norm=norm,
#     888         colorizer=colorizer,
#     889         interpolation=interpolation,
#     890         origin=origin,
#     891         filternorm=filternorm,
#     892         filterrad=filterrad,
#     893         resample=resample,
#     894         interpolation_stage=interpolation_stage,
#     895         **kwargs
#     896     )
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\image.py:263, in _ImageBase.__init__(self, ax, cmap, norm, colorizer, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     250 def __init__(self, ax,
#     251              cmap=None,
#     252              norm=None,
#    (...)
#     261              **kwargs
#     262              ):
# --> 263     super().__init__(self._get_colorizer(cmap, norm, colorizer))
#     264     if origin is None:
#     265         origin = mpl.rcParams['image.origin']
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\colorizer.py:610, in _ScalarMappable._get_colorizer(cmap, norm, colorizer)
#     606     _ScalarMappable._check_exclusionary_keywords(
#     607         Colorizer, cmap=cmap, norm=norm
#     608     )
#     609     return colorizer
# --> 610 return Colorizer(cmap, norm)
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\colorizer.py:56, in Colorizer.__init__(self, cmap, norm)
#      53 def __init__(self, cmap=None, norm=None):
#      55     self._cmap = None
# ---> 56     self._set_cmap(cmap)
#      58     self._id_norm = None
#      59     self._norm = None
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\colorizer.py:237, in Colorizer._set_cmap(self, cmap)
#     235 from matplotlib import cm
#     236 in_init = self._cmap is None
# --> 237 self._cmap = cm._ensure_cmap(cmap)
#     238 if not in_init:
#     239     self.changed()
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\cm.py:308, in _ensure_cmap(cmap)
#     305 cmap_name = cmap if cmap is not None else mpl.rcParams["image.cmap"]
#     306 # use check_in_list to ensure type stability of the exception raised by
#     307 # the internal usage of this (ValueError vs KeyError)
# --> 308 if cmap_name not in _colormaps:
#     309     _api.check_in_list(sorted(_colormaps), cmap=cmap_name)
#     310 return mpl.colormaps[cmap_name]
#
# File c:\Users\MSI\.conda\envs\test310\lib\_collections_abc.py:830, in Mapping.__contains__(self, key)
#     828 def __contains__(self, key):
#     829     try:
# --> 830         self[key]
#     831     except KeyError:
#     832         return False
#
# File c:\Users\MSI\.conda\envs\test310\lib\site-packages\matplotlib\cm.py:96, in ColormapRegistry.__getitem__(self, item)
#      94 def __getitem__(self, item):
#      95     try:
# ---> 96         return self._cmaps[item].copy()
#      97     except KeyError:
#      98         raise KeyError(f"{item!r} is not a known colormap name") from None
#
# TypeError: unhashable type: 'numpy.ndarray'

# %% [markdown]
# EJERCICIO 6

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [10, 5]
size_imagen=800
imagen = np.ones((size_imagen, size_imagen, 3), dtype=np.uint8) * 255

primerOctavo = size_imagen // 8
segundoOctavo = size_imagen // 4
tercerOctavo = size_imagen // 8 * 3
cuartoOctavo = size_imagen // 2
quintoOctavo = size_imagen // 8 * 5
sextoOctavo = size_imagen // 8 * 6
septimoOctavo = size_imagen // 8 * 7

for i in range(size_imagen):
    for j in range(size_imagen):
        #Por filas
        if i < primerOctavo and j < primerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i <segundoOctavo and j < primerOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= tercerOctavo and i < cuartoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= quintoOctavo and i < sextoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= septimoOctavo and i < size_imagen and j <= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        
         
        elif i < primerOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= sextoOctavo and i < septimoOctavo and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= primerOctavo and j < segundoOctavo:
            imagen[i, j] = [255, 255, 255]

        elif i < primerOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i < segundoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= segundoOctavo and i < tercerOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= septimoOctavo and i < size_imagen and j >= segundoOctavo and j < tercerOctavo:
            imagen[i, j] = [0, 0, 0]

        elif i < primerOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= tercerOctavo and j < cuartoOctavo:
            imagen[i, j] = [255, 255, 255]

        elif i < primerOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i < segundoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= septimoOctavo and i < size_imagen and j >= cuartoOctavo and j < quintoOctavo:
            imagen[i, j] = [0, 0, 0]

        elif i < primerOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= segundoOctavo and i < tercerOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= quintoOctavo and j < sextoOctavo:
            imagen[i, j] = [255, 255, 255]

        elif i < primerOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= primerOctavo and i < segundoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= segundoOctavo and i < tercerOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 255]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [0, 0, 0]
        elif i >= sextoOctavo and i < septimoOctavo and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [255, 255, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= sextoOctavo and j < septimoOctavo:
            imagen[i, j] = [0, 0, 0]

        elif i < primerOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= primerOctavo and i < segundoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]
        elif i >= segundoOctavo and i < tercerOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= tercerOctavo and i < cuartoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]
        elif i >= cuartoOctavo and i < quintoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= quintoOctavo and i < sextoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]
        elif i >= sextoOctavo and i < septimoOctavo and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [0, 0, 0]
        elif i >= septimoOctavo and i < size_imagen and j >= septimoOctavo and j < size_imagen:
            imagen[i, j] = [255, 255, 255]


plt.imsave('imagen_cuadrado_original.jpg', imagen)
plt.figure()
plt.imshow(imagen)
plt.axis('off')
plt.title("Imagen con cuadrantes")
plt.show()
