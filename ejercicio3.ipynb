# %% [markdown]
# RGB A HSV

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
imagen1=cv2.imread("imagen_nueva.jpg")
img=cv2.cvtColor(imagen1, cv2.COLOR_BGR2RGB)
def RGB2HSV(img):
    img=img.astype(np.float32)
    img=img/255
    new_img=np.zeros_like(img)

    maxChanel=np.argmax(img,axis=2)
    maxValue=np.amax(img,axis=2)
    minChanel=np.argmin(img,axis=2)
    minValue=np.amin(img,axis=2)
    #calculo de valores
    new_img[...,2]=maxValue
    #calculo de saturacion
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if maxValue[i,j]==0:
                new_img[i,j,1]=0
            elif maxValue[i,j]!=0:
                new_img[i,j,1]=(new_img[i,j,2]-minValue[i,j])/new_img[i,j,2]

    #Calculo de Hue
    for i in range (img.shape[0]):
        for j in range (img.shape[1]):
            if sum(img[i,j,...])/3==img[i,j,0]:
                new_img[i,j,0]=0
            elif maxChanel[i,j]==0:#R
                new_img[i,j,0]=60*((img[i,j,1]-img[i,j,2])/(new_img[i,j,2]-minValue[i,j]))
            elif maxChanel[i,j]==1:#G
                new_img[i,j,0]=120+60*(img[i,j,2]-img[i,j,0]/(new_img[i,j,2]-minValue[i,j]))
            elif maxChanel[i,j]==2:#B
                new_img[i,j,0]=240+60*(img[i,j,0]-img[i,j,1]/(new_img[i,j,2]-minValue[i,j]))
        img2=new_img[...,0]<0
        new_img[img2,0]=new_img[img2,0]+360 #trabajamos con grados y que no se puede sobrepasar los 360
    return new_img

hsv_img=RGB2HSV(img)
fig,axs=plt.subplots(1,4,figsize=(25,10))
axs[0].imshow(img)
axs[0].set_title('Imagen original')
fig_img=axs[1].imshow(hsv_img[...,0],cmap='gray',vmin=0,vmax=360)
axs[1].set_title('canal hue')
fig_img=axs[2].imshow(hsv_img[...,1],cmap='gray',vmin=0,vmax=1)
axs[2].set_title('Canal saturacion')
fig_img=axs[3].imshow(hsv_img[...,2],cmap='gray',vmin=0,vmax=1)
axs[3].set_title('canal value')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 40
#      37         new_img[img2,0]=new_img[img2,0]+360 #trabajamos con grados y que no se puede sobrepasar los 360
#      38     return new_img
# ---> 40 hsv_img=RGB2HSV(img)
#      41 fig,axs=plt.subplots(1,4,figsize=(25,10))
#      42 axs[0].imshow(img)
#
# Cell In[6], line 20, in RGB2HSV(img)
#      18 for i in range(img.shape[0]):
#      19     for j in range(img.shape[1]):
# ---> 20         if maxValue[i,j]==0:
#      21             new_img[i,j,1]=0
#      22         elif maxValue[i,j]!=0:
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
Imagen = cv2.imread('imagen_nueva.jpg')
img= cv2.cvtColor(Imagen, cv2.COLOR_BGR2RGB)
def RGB2HSV(img):
    img = img.astype(np.float32)
    img = img/255.
    new_img = np.zeros_like(img)

    maxChannel = np.argmax(img,axis=2)
    maxValue = np.amax(img,axis=2)
    minChannel = np.argmin(img,axis=2)
    minValue = np.amin(img,axis=2)
    #value 
    new_img[...,2] = maxValue

    #saturation
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if maxValue[i,j]==0:
                new_img[i,j,1] = 0
            elif maxValue[i,j] != 0:
                new_img[i,j,1] = (new_img[i,j,2]-minValue[i,j])/new_img[i,j,2]

    #hue 
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if sum(img[i,j,...])/3 == img[i,j,0]:
                new_img[i,j,0] = 0
            elif maxChannel[i,j] == 0: #R 
                new_img[i,j,0] = 60 * ((img[i,j,1]-img[i,j,2])/(new_img[i,j,2]-minValue[i,j]))
            elif maxChannel[i,j] == 1: #G
                new_img[i,j,0] = 120 + 60 * (img[i,j,2]-img[i,j,0])/(new_img[i,j,2]-minValue[i,j])
            elif maxChannel[i,j] == 2: #B
                new_img[i,j,0] = 240 + 60 * (img[i,j,0]-img[i,j,1])/(new_img[i,j,2]-minValue[i,j])

        img2= new_img[...,0] < 0
        new_img[img2,0]   =  new_img[img2,0] + 360
    return new_img 

hsv_img =  RGB2HSV(img) 
fig, axs = plt.subplots(1,4,figsize=(25,10))
axs[0].imshow(img)
axs[0].set_title('Imagen')
fig_img = axs[1].imshow(hsv_img[...,0],cmap='gray',vmin=0,vmax=360)

axs[1].set_title('Canal Hue')
fig_img = axs[2].imshow(hsv_img[...,1],cmap='gray',vmin=0,vmax=1)

axs[2].set_title('Canal Saturación')
fig_img = axs[3].imshow(hsv_img[...,2],cmap='gray',vmin=0,vmax=1)

axs[3].set_title('Canal Value')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 42
#      39         new_img[img2,0]   =  new_img[img2,0] + 360
#      40     return new_img
# ---> 42 hsv_img =  RGB2HSV(img)
#      43 fig, axs = plt.subplots(1,4,figsize=(25,10))
#      44 axs[0].imshow(img)
#
# Cell In[9], line 39, in RGB2HSV(img)
#      36             new_img[i,j,0] = 240 + 60 * (img[i,j,0]-img[i,j,1])/(new_img[i,j,2]-minValue[i,j])
#      38     img2= new_img[...,0] < 0
# ---> 39     new_img[img2,0]   =  new_img[img2,0] + 360
#      40 return new_img
#
# KeyboardInterrupt:
