# %%
palabra1 = input('Introduce la primera palabra: ')
palabra2 = input('Introduce la segunda palabra: ')
palabra1_limpia = palabra1.replace(' ', '').lower()
palabra2_limpia = palabra2.replace(' ', '').lower()

letras1 = sorted(palabra1_limpia)
letras2 = sorted(palabra2_limpia)
    
if letras1 == letras2:
    print(f'"{palabra1}" y "{palabra2}" son anagramas')
else:
    print(f'"{palabra1}" y "{palabra2}" NO son anagramas')
# Out:
# "vale" y "lave" son anagramas
