# %%
cantidad = int(input('¿Cuántos números deseas ingresar? '))
    
if cantidad <= 0:
    print('La cantidad debe ser mayor a 0')
else:
    numeros = []
    for i in range(cantidad):
        num = float(input(f'Introduce el número {i+1}: '))
        numeros.append(num)
        
    numeros_ordenados = bubble_sort(numeros)
        
    print(f'\nNúmeros originales: {numeros}')
    print(f'Números ordenados: {numeros_ordenados}')
    
def bubble_sort(numeros):
    n = len(numeros)
    lista = numeros.copy()
    
    for i in range(n):
        for j in range(0, n - i - 1):
            if lista[j] > lista[j + 1]:
                lista[j], lista[j + 1] = lista[j + 1], lista[j]
    return lista
# Out:
# Números originales: [67.0, 45.0, 89.0]
# Números ordenados: [45.0, 67.0, 89.0]
